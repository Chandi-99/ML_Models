# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Chandi\\Desktop\\Data\\wine.csv")
df
# Out:
#      1  14.23  1.71  2.43  15.6  127   2.8  3.06   .28  2.29   5.64  1.04  \
# 0    1  13.20  1.78  2.14  11.2  100  2.65  2.76  0.26  1.28   4.38  1.05
# 1    1  13.16  2.36  2.67  18.6  101  2.80  3.24  0.30  2.81   5.68  1.03
# 2    1  14.37  1.95  2.50  16.8  113  3.85  3.49  0.24  2.18   7.80  0.86
# 3    1  13.24  2.59  2.87  21.0  118  2.80  2.69  0.39  1.82   4.32  1.04
# 4    1  14.20  1.76  2.45  15.2  112  3.27  3.39  0.34  1.97   6.75  1.05
# ..  ..    ...   ...   ...   ...  ...   ...   ...   ...   ...    ...   ...
# 172  3  13.71  5.65  2.45  20.5   95  1.68  0.61  0.52  1.06   7.70  0.64
# 173  3  13.40  3.91  2.48  23.0  102  1.80  0.75  0.43  1.41   7.30  0.70
# 174  3  13.27  4.28  2.26  20.0  120  1.59  0.69  0.43  1.35  10.20  0.59
# 175  3  13.17  2.59  2.37  20.0  120  1.65  0.68  0.53  1.46   9.30  0.60
# 176  3  14.13  4.10  2.74  24.5   96  2.05  0.76  0.56  1.35   9.20  0.61
#
#      3.92  1065
# 0    3.40  1050
# 1    3.17  1185
# 2    3.45  1480
# ...

# %%
colnames=['Class', 'Alcohol', 'Malic acid', 'Ash','Alcalinity of ash','Magnesium','Total phenols','Flavanoids','Nonflavanoid phenols','Proanthocyanine','Color Intensity','Hue','OD280/OD315 of diluted wines','Proline'] 
df = pd.read_csv('C:\\Users\\Chandi\\Desktop\\Data\\wine.csv', names=colnames, header=None)
df
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanine  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
df[df.Class==1].head()
# Out:
#    Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
# 3      1    14.37        1.95  2.50               16.8        113
# 4      1    13.24        2.59  2.87               21.0        118
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanine  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
# 3           3.85        3.49                  0.24             2.18
# 4           2.80        2.69                  0.39             1.82
#
#    Color Intensity   Hue  OD280/OD315 of diluted wines  Proline
# 0             5.64  1.04                          3.92     1065
# ...

# %%
df[df.Class==2].head()
# Out:
#     Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 59      2    12.37        0.94  1.36               10.6         88
# 60      2    12.33        1.10  2.28               16.0        101
# 61      2    12.64        1.36  2.02               16.8        100
# 62      2    13.67        1.25  1.92               18.0         94
# 63      2    12.37        1.13  2.16               19.0         87
#
#     Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanine  \
# 59           1.98        0.57                  0.28             0.42
# 60           2.05        1.09                  0.63             0.41
# 61           2.02        1.41                  0.53             0.62
# 62           2.10        1.79                  0.32             0.73
# 63           3.50        3.10                  0.19             1.87
#
#     Color Intensity   Hue  OD280/OD315 of diluted wines  Proline
# 59             1.95  1.05                          1.82      520
# ...

# %%
df[df.Class==3].head()
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 130      3    12.86        1.35  2.32               18.0        122
# 131      3    12.88        2.99  2.40               20.0        104
# 132      3    12.81        2.31  2.40               24.0         98
# 133      3    12.70        3.55  2.36               21.5        106
# 134      3    12.51        1.24  2.25               17.5         85
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanine  \
# 130           1.51        1.25                  0.21             0.94
# 131           1.30        1.22                  0.24             0.83
# 132           1.15        1.09                  0.27             0.83
# 133           1.70        1.20                  0.17             0.84
# 134           2.00        0.58                  0.60             1.25
#
#      Color Intensity   Hue  OD280/OD315 of diluted wines  Proline
# 130             4.10  0.76                          1.29      630
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.xlabel('Alcohol')
plt.ylabel('Alcalinity of ash')
plt.scatter(df0['Alcohol'], df0['Alcalinity of ash'],color="green",marker='+')
plt.scatter(df1['Alcohol'], df1['Alcalinity of ash'],color="blue",marker='.')
plt.scatter(df2['Alcohol'], df2['Alcalinity of ash'],color="red",marker='+')

# %%
wines = ["wine 1", "wine 2", "wine 3"]
df['Wine_name'] =df.Class.apply(lambda x:wines[x-1] )
df['Wine_name']
# Out:
# 0      wine 1
# 1      wine 1
# 2      wine 1
# 3      wine 1
# 4      wine 1
#         ...
# 173    wine 3
# 174    wine 3
# 175    wine 3
# 176    wine 3
# 177    wine 3
# Name: Wine_name, Length: 178, dtype: object

# %%
df0 = df[:59]
df1 = df[59:130]
df2 = df[130:]

# %%
df0
# Out:
#     Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0       1    14.23        1.71  2.43               15.6        127
# 1       1    13.20        1.78  2.14               11.2        100
# 2       1    13.16        2.36  2.67               18.6        101
# 3       1    14.37        1.95  2.50               16.8        113
# 4       1    13.24        2.59  2.87               21.0        118
# 5       1    14.20        1.76  2.45               15.2        112
# 6       1    14.39        1.87  2.45               14.6         96
# 7       1    14.06        2.15  2.61               17.6        121
# 8       1    14.83        1.64  2.17               14.0         97
# 9       1    13.86        1.35  2.27               16.0         98
# 10      1    14.10        2.16  2.30               18.0        105
# 11      1    14.12        1.48  2.32               16.8         95
# 12      1    13.75        1.73  2.41               16.0         89
# ...

# %%
plt.xlabel('Class')
plt.ylabel('Wine_name')
plt.scatter(df0['Alcohol'], df0['Alcalinity of ash'],color="green",marker='+')
plt.scatter(df1['Alcohol'], df1['Alcalinity of ash'],color="blue",marker='.')
plt.scatter(df2['Alcohol'], df2['Alcalinity of ash'],color="red",marker='+')

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['Class','Wine_name'], axis='columns')
y = df.Class

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4)

# %%
len(X_train)
# Out:
# 106

# %%
len(X_test)
# Out:
# 72

# %%
from sklearn.neighbors import KNeighborsClassifier
accuracy = 0
for x in range(1,10):
    knn = KNeighborsClassifier(n_neighbors=x)
    knn.fit(X_train, y_train)
    temp = knn.score(X_test, y_test)
    print(temp)
    if temp > accuracy:
        N = x
        accuracy = temp
print("Number of Neighbours :", N)
print("Accuracy :", accuracy)
# Out:
# 0.75
# 0.6666666666666666
# 0.6944444444444444
# 0.6805555555555556
# 0.7222222222222222
# 0.6805555555555556
# 0.7361111111111112
# 0.6527777777777778
# 0.6944444444444444
# Number of Neighbours : 1
# Accuracy : 0.75

# %%
# Out:
# KNeighborsClassifier(n_neighbors=11)

# %%
# Out:
# 0.7083333333333334

# %%
knn.predict(X_test)
# Out:
# array([2, 1, 1, 1, 1, 3, 1, 2, 3, 1, 2, 3, 2, 3, 2, 3, 2, 2, 2, 3, 1, 3,
#        3, 2, 3, 2, 1, 2, 3, 3, 1, 1, 2, 1, 3, 2, 2, 3, 1, 3, 1, 1, 2, 1,
#        3, 3, 1, 1, 1, 2, 2, 2, 1, 3, 2, 3, 1, 3, 2, 3, 3, 1, 3, 1, 3, 3,
#        1, 2, 2, 2, 1, 3], dtype=int64)

# %%
y_test
# Out:
# 127    2
# 45     1
# 6      1
# 13     1
# 17     1
#       ..
# 85     2
# 91     2
# 121    2
# 44     1
# 149    3
# Name: Class, Length: 72, dtype: int64
